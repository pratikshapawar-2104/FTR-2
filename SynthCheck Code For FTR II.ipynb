# %% [markdown]
# # SynthCheck:A Synthetic Image Identification Using Deep Learning

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import LearningRateScheduler 
from matplotlib import pyplot as plt
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications import VGG19,EfficientNetB0,ResNet50
import numpy as np

# %%
# Load image dataset
data = tf.keras.utils.image_dataset_from_directory(r"D:\## BE Sem II\Project stage II\Cifake Dataset\TRAIN", image_size=(32, 32))
# Out:
# Found 11149 files belonging to 2 classes.

# %%
# Visualize a batch of images
data_it = data.as_numpy_iterator()
batch = data_it.next()

fig, ax = plt.subplots(ncols=8, figsize=(10, 10))
for idx, img in enumerate(batch[0][:8]):
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(batch[1][idx])

print(batch[0].min())
print(batch[0].max())
# Out:
# 0.0
# 255.0

# %%
# Scale pixel values to the range [0, 1]
data = data.map(lambda x, y : (x/255, y))

# Visualize a scaled batch of images
scaled_it = data.as_numpy_iterator()
batch = scaled_it.next()

fig, ax = plt.subplots(ncols=8, figsize=(10, 10))
for idx, img in enumerate(batch[0][:8]):
    ax[idx].imshow(img.astype(float))
    ax[idx].title.set_text(batch[1][idx])

# %%
# Split the dataset
train_size = int(len(data) * 0.7)
cv_size = int(len(data) * 0.2)
test_size = int(len(data) * 0.1) + 1

train = data.take(train_size)
cv = data.skip(train_size).take(cv_size)
test = data.skip(train_size + cv_size).take(test_size)

print(len(train) + len(cv) + len(test))
# Out:
# 348

# %% [markdown]
# # CNN

# %%
# Define the CNN model with enhancements
model = models.Sequential()

model.add(layers.Conv2D(64, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Conv2D(256, (3, 3), activation='relu'))
model.add(layers.BatchNormalization())

model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

# %%
# Learning rate scheduler
initial_learning_rate = 0.001
def lr_scheduler(epoch, lr):
    return lr * 0.95  # Adjust the decay factor as needed
lr_schedule = LearningRateScheduler(lr_scheduler)
optimizer = Adam(learning_rate=initial_learning_rate)

# %%
# Compile the model
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train the model
history = model.fit(data, validation_data=cv, epochs=10, callbacks=[lr_schedule])
# Out:
# Epoch 1/10
# 349/349 [==============================] - 34s 98ms/step - loss: 0.3134 - accuracy: 0.8689 - val_loss: 0.3421 - val_accuracy: 0.8528 - lr: 9.0250e-04
# Epoch 2/10
# 349/349 [==============================] - 36s 103ms/step - loss: 0.2605 - accuracy: 0.8951 - val_loss: 0.4916 - val_accuracy: 0.7867 - lr: 8.5737e-04
# Epoch 3/10
# 349/349 [==============================] - 29s 84ms/step - loss: 0.2197 - accuracy: 0.9132 - val_loss: 0.2554 - val_accuracy: 0.8868 - lr: 8.1451e-04
# Epoch 4/10
# 349/349 [==============================] - 29s 83ms/step - loss: 0.2020 - accuracy: 0.9204 - val_loss: 0.1343 - val_accuracy: 0.9524 - lr: 7.7378e-04
# Epoch 5/10
# 349/349 [==============================] - 29s 82ms/step - loss: 0.1705 - accuracy: 0.9338 - val_loss: 0.1172 - val_accuracy: 0.9574 - lr: 7.3509e-04
# Epoch 6/10
# 349/349 [==============================] - 29s 83ms/step - loss: 0.1422 - accuracy: 0.9439 - val_loss: 0.1388 - val_accuracy: 0.9470 - lr: 6.9834e-04
# Epoch 7/10
# 349/349 [==============================] - 29s 83ms/step - loss: 0.1227 - accuracy: 0.9509 - val_loss: 0.0740 - val_accuracy: 0.9715 - lr: 6.6342e-04
# Epoch 8/10
# 349/349 [==============================] - 29s 83ms/step - loss: 0.0936 - accuracy: 0.9648 - val_loss: 0.0447 - val_accuracy: 0.9832 - lr: 6.3025e-04
# Epoch 9/10
# 349/349 [==============================] - 29s 83ms/step - loss: 0.0755 - accuracy: 0.9718 - val_loss: 0.1177 - val_accuracy: 0.9556 - lr: 5.9874e-04
# Epoch 10/10
# 349/349 [==============================] - 29s 83ms/step - loss: 0.0623 - accuracy: 0.9778 - val_loss: 0.0852 - val_accuracy: 0.9660 - lr: 5.6880e-04

# %%
# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(test)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')
# Out:
# 35/35 [==============================] - 6s 29ms/step - loss: 0.0568 - accuracy: 0.9786
# Test Accuracy: 97.86%

# %%
# Plot accuracy and loss
plt.figure(figsize=(12, 4))

# Plot training & validation accuracy values
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')
# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()

# %%
from tensorflow.keras.metrics import Precision, Recall

pre = Precision()
rec = Recall()


for batch in test.as_numpy_iterator(): 
    X, y = batch
    yhat = model.predict(X)
    pre.update_state(y, yhat)
    rec.update_state(y, yhat)
# Out:
# 1/1 [==============================] - 0s 417ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 70ms/step

# %%
print(f'Precision: {pre.result().numpy()}, Recall: {rec.result().numpy()}')
# Out:
# Precision: 0.9956331849098206, Recall: 0.9681528806686401

# %%
from tensorflow.keras.models import load_model
from keras.models import load_model
from tensorflow import keras

# %%
model.save("AIGeneratedModelcnn.h5")

# %%
model_new = keras.models.load_model("AIGeneratedModelcnn.h5")

# %%
import cv2
import matplotlib.pyplot as plt

# Load the image
image_path = r"C:\Users\vaibh\Downloads\data\ai3.png"
try:
    img = cv2.imread(image_path)

    # Check if the image is loaded successfully
    if img is None:
        raise FileNotFoundError(f"Could not read the image from {image_path}")

    # Resize the image to a larger size
    img = cv2.resize(img, (800, 600))

    # Convert from BGR to RGB
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    # Display the resized image
    plt.imshow(img)
    plt.show()

except Exception as e:
    print(f"Error: {e}")

# %%
import numpy as np

# %%
resize = tf.image.resize(img, (32, 32))

y_pred = model.predict(np.expand_dims(resize/255, 0))
# Out:
# 1/1 [==============================] - 0s 321ms/step

# %%
y_pred
# Out:
# array([[0.40145215]], dtype=float32)

# %%
if y_pred > 0.5: 
    print(f'Predicted class: REAL')
else:
    print(f'Predicted class: SYNTHETIC')
# Out:
# Predicted class: SYNTHETIC

# %% [markdown]
# # VGG19

# %%
# Define a VGG19 model for image classification
vgg_model = VGG19(weights='imagenet', include_top=False, input_shape=(32, 32, 3))
vgg_model.trainable = False

# %%
# Create a new model by adding a few layers on top of the VGG19 model
vgg_based_model = models.Sequential()
vgg_based_model.add(vgg_model)
vgg_based_model.add(layers.Flatten())
vgg_based_model.add(layers.Dense(256, activation='relu'))
vgg_based_model.add(layers.BatchNormalization())
vgg_based_model.add(layers.Dropout(0.5))
vgg_based_model.add(layers.Dense(128, activation='relu'))
vgg_based_model.add(layers.Dense(1, activation='sigmoid'))

# %%
# Learning rate scheduler for the VGG19-based model
vgg_initial_learning_rate = 0.001
vgg_lr_schedule = LearningRateScheduler(lambda epoch, lr: lr * 0.95)
vgg_optimizer = Adam(learning_rate=vgg_initial_learning_rate)

# %%
# Compile the VGG19-based model
vgg_based_model.compile(optimizer=vgg_optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train the VGG19-based model
vgg_history = vgg_based_model.fit(data, validation_data=cv, epochs=10, callbacks=[vgg_lr_schedule])
# Out:
# Epoch 1/10
# 349/349 [==============================] - 100s 279ms/step - loss: 0.4799 - accuracy: 0.7781 - val_loss: 0.3527 - val_accuracy: 0.8564 - lr: 9.5000e-04
# Epoch 2/10
# 349/349 [==============================] - 91s 261ms/step - loss: 0.4180 - accuracy: 0.8105 - val_loss: 0.3199 - val_accuracy: 0.8678 - lr: 9.0250e-04
# Epoch 3/10
# 349/349 [==============================] - 58s 165ms/step - loss: 0.3889 - accuracy: 0.8226 - val_loss: 0.3037 - val_accuracy: 0.8777 - lr: 8.5737e-04
# Epoch 4/10
# 349/349 [==============================] - 61s 175ms/step - loss: 0.3747 - accuracy: 0.8322 - val_loss: 0.2951 - val_accuracy: 0.8809 - lr: 8.1451e-04
# Epoch 5/10
# 349/349 [==============================] - 63s 180ms/step - loss: 0.3593 - accuracy: 0.8414 - val_loss: 0.2821 - val_accuracy: 0.8918 - lr: 7.7378e-04
# Epoch 6/10
# 349/349 [==============================] - 60s 173ms/step - loss: 0.3556 - accuracy: 0.8418 - val_loss: 0.2575 - val_accuracy: 0.8986 - lr: 7.3509e-04
# Epoch 7/10
# 349/349 [==============================] - 72s 206ms/step - loss: 0.3418 - accuracy: 0.8527 - val_loss: 0.2549 - val_accuracy: 0.9008 - lr: 6.9834e-04
# Epoch 8/10
# 349/349 [==============================] - 74s 212ms/step - loss: 0.3334 - accuracy: 0.8539 - val_loss: 0.2499 - val_accuracy: 0.9008 - lr: 6.6342e-04
# Epoch 9/10
# 349/349 [==============================] - 97s 278ms/step - loss: 0.3282 - accuracy: 0.8605 - val_loss: 0.2327 - val_accuracy: 0.9099 - lr: 6.3025e-04
# Epoch 10/10
# 349/349 [==============================] - 97s 278ms/step - loss: 0.3199 - accuracy: 0.8631 - val_loss: 0.2272 - val_accuracy: 0.9108 - lr: 5.9874e-04

# %%
# Evaluate the VGG19-based model on the test set
vgg_test_loss, vgg_test_accuracy = vgg_based_model.evaluate(test)
print(f'VGG19 Test Accuracy: {vgg_test_accuracy * 100:.2f}%')
# Out:
# 35/35 [==============================] - 13s 215ms/step - loss: 0.2576 - accuracy: 0.8964
# VGG19 Test Accuracy: 89.64%

# %%
plt.figure(figsize=(12, 4))
# Plot training & validation accuracy values
plt.subplot(1, 2, 1)
plt.plot(vgg_history.history['accuracy'], label='VGG-19 Train')
plt.plot(vgg_history.history['val_accuracy'], label='VGG-19 Validation')
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# %%
# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(vgg_history.history['loss'], label='VGG-19 Train')
plt.plot(vgg_history.history['val_loss'], label='VGG-19 Validation')
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
from tensorflow.keras.metrics import Precision, Recall

pre = Precision()
rec = Recall()

for batch in test.as_numpy_iterator(): 
    X, y = batch
    yhat = vgg_based_model.predict(X)
    pre.update_state(y, yhat)
    rec.update_state(y, yhat)
# Out:
# 1/1 [==============================] - 1s 673ms/step
# 1/1 [==============================] - 0s 258ms/step
# 1/1 [==============================] - 0s 260ms/step
# 1/1 [==============================] - 0s 255ms/step
# 1/1 [==============================] - 0s 267ms/step
# 1/1 [==============================] - 0s 280ms/step
# 1/1 [==============================] - 0s 262ms/step
# 1/1 [==============================] - 0s 258ms/step
# 1/1 [==============================] - 0s 254ms/step
# 1/1 [==============================] - 0s 260ms/step
# 1/1 [==============================] - 0s 258ms/step
# 1/1 [==============================] - 0s 254ms/step
# 1/1 [==============================] - 0s 260ms/step
# 1/1 [==============================] - 0s 256ms/step
# 1/1 [==============================] - 0s 259ms/step
# 1/1 [==============================] - 0s 262ms/step
# 1/1 [==============================] - 0s 270ms/step
# 1/1 [==============================] - 0s 257ms/step
# 1/1 [==============================] - 0s 270ms/step
# 1/1 [==============================] - 0s 252ms/step
# 1/1 [==============================] - 0s 256ms/step
# 1/1 [==============================] - 0s 269ms/step
# 1/1 [==============================] - 0s 259ms/step
# 1/1 [==============================] - 0s 266ms/step
# 1/1 [==============================] - 0s 263ms/step
# 1/1 [==============================] - 0s 258ms/step
# 1/1 [==============================] - 0s 258ms/step
# 1/1 [==============================] - 0s 262ms/step
# 1/1 [==============================] - 0s 265ms/step
# 1/1 [==============================] - 0s 257ms/step
# 1/1 [==============================] - 0s 277ms/step
# 1/1 [==============================] - 0s 254ms/step
# 1/1 [==============================] - 0s 303ms/step
# 1/1 [==============================] - 0s 301ms/step
# 1/1 [==============================] - 0s 277ms/step

# %%
print(f'Precision: {pre.result().numpy()}, Recall: {rec.result().numpy()}')
# Out:
# Precision: 0.8720173239707947, Recall: 0.8777292370796204

# %%
vgg_based_model.save("AIGeneratedModelvgg.h5")

# %%
vgg_based_model_new = keras.models.load_model("AIGeneratedModelvgg.h5")

# %%
import cv2
import matplotlib.pyplot as plt

# Load the image
image_path = r"C:\Users\vaibh\Downloads\data\real2.jpeg"

try:
    img = cv2.imread(image_path)

    # Check if the image is loaded successfully
    if img is None:
        raise FileNotFoundError(f"Could not read the image from {image_path}")

    # Resize the image to a larger size
    img = cv2.resize(img, (800, 600))

    # Convert from BGR to RGB
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    # Display the resized image
    plt.imshow(img)
    plt.show()

except Exception as e:
    print(f"Error: {e}")

# %%
import numpy as np

# %%
resize = tf.image.resize(img, (32, 32))

y_pred = vgg_based_model.predict(np.expand_dims(resize/255, 0))
# Out:
# 1/1 [==============================] - 1s 528ms/step

# %%
y_pred
# Out:
# array([[0.85279125]], dtype=float32)

# %%
if y_pred > 0.5: 
    print(f'Predicted class: REAL')
else:
    print(f'Predicted class: SYNTHETIC')
# Out:
# Predicted class: REAL

# %% [markdown]
# # ResNet50

# %%
# Define a ResNet model for image classification
resnet_model = ResNet50(weights='imagenet', include_top=False, input_shape=(32, 32, 3))
resnet_model.trainable = False  # Freeze the weights of the pre-trained model

# %%
# Create a new model by adding a few layers on top of the ResNet model
resnet_based_model = models.Sequential()
resnet_based_model.add(resnet_model)
resnet_based_model.add(layers.Flatten())
resnet_based_model.add(layers.Dense(256, activation='relu'))
resnet_based_model.add(layers.BatchNormalization())
resnet_based_model.add(layers.Dropout(0.5))
resnet_based_model.add(layers.Dense(128, activation='relu'))
resnet_based_model.add(layers.Dense(1, activation='sigmoid'))

# %%
# Learning rate scheduler for the ResNet-based model
resnet_initial_learning_rate = 0.001
resnet_lr_schedule = LearningRateScheduler(lambda epoch, lr: lr * 0.95)
resnet_optimizer = Adam(learning_rate=resnet_initial_learning_rate)

# %%
# Compile the ResNet-based model
resnet_based_model.compile(optimizer=resnet_optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train the ResNet-based model
resnet_history = resnet_based_model.fit(data, validation_data=cv, epochs=10, callbacks=[resnet_lr_schedule])
# Out:
# Epoch 1/10
# 349/349 [==============================] - 64s 184ms/step - loss: 0.4253 - accuracy: 0.8037 - val_loss: 0.5257 - val_accuracy: 0.7378 - lr: 1.2209e-04
# Epoch 2/10
# 349/349 [==============================] - 64s 183ms/step - loss: 0.4300 - accuracy: 0.8012 - val_loss: 0.5492 - val_accuracy: 0.7319 - lr: 1.1598e-04
# Epoch 3/10
# 349/349 [==============================] - 64s 184ms/step - loss: 0.4236 - accuracy: 0.8043 - val_loss: 0.4545 - val_accuracy: 0.7808 - lr: 1.1018e-04
# Epoch 4/10
# 349/349 [==============================] - 65s 184ms/step - loss: 0.4260 - accuracy: 0.8030 - val_loss: 0.5637 - val_accuracy: 0.7360 - lr: 1.0467e-04
# Epoch 5/10
# 349/349 [==============================] - 65s 184ms/step - loss: 0.4299 - accuracy: 0.7975 - val_loss: 0.5866 - val_accuracy: 0.7092 - lr: 9.9440e-05
# Epoch 6/10
# 349/349 [==============================] - 65s 186ms/step - loss: 0.4250 - accuracy: 0.8038 - val_loss: 0.5474 - val_accuracy: 0.7264 - lr: 9.4468e-05
# Epoch 7/10
# 349/349 [==============================] - 65s 186ms/step - loss: 0.4253 - accuracy: 0.8064 - val_loss: 0.4179 - val_accuracy: 0.8062 - lr: 8.9745e-05
# Epoch 8/10
# 349/349 [==============================] - 65s 186ms/step - loss: 0.4278 - accuracy: 0.8025 - val_loss: 0.4830 - val_accuracy: 0.7613 - lr: 8.5258e-05
# Epoch 9/10
# 349/349 [==============================] - 65s 185ms/step - loss: 0.4224 - accuracy: 0.8061 - val_loss: 0.4259 - val_accuracy: 0.7957 - lr: 8.0995e-05
# Epoch 10/10
# 349/349 [==============================] - 61s 175ms/step - loss: 0.4198 - accuracy: 0.8042 - val_loss: 0.4510 - val_accuracy: 0.7758 - lr: 7.6945e-05

# %%
# Evaluate the ResNet-based model on the test set
resnet_test_loss, resnet_test_accuracy = resnet_based_model.evaluate(test)
print(f'ResNet Test Accuracy: {resnet_test_accuracy * 100:.2f}%')
# Out:
# 35/35 [==============================] - 6s 106ms/step - loss: 0.4553 - accuracy: 0.7804
# ResNet Test Accuracy: 78.04%

# %%
plt.figure(figsize=(12, 4))
# Plot training & validation accuracy values
plt.subplot(1, 2, 1)
plt.plot(resnet_history.history['accuracy'], label='Resnet Train')
plt.plot(resnet_history.history['val_accuracy'], label='Resnet Validation')
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# %%
# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(resnet_history.history['loss'], label='Resnet Train')
plt.plot(resnet_history.history['val_loss'], label='Resnet Validation')
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
from tensorflow.keras.metrics import Precision, Recall

pre = Precision()
rec = Recall()


for batch in test.as_numpy_iterator(): 
    X, y = batch
    yhat = resnet_based_model.predict(X)
    pre.update_state(y, yhat)
    rec.update_state(y, yhat)
# Out:
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 146ms/step

# %%
print(f'Precision: {pre.result().numpy()}, Recall: {rec.result().numpy()}')
# Out:
# Precision: 0.8637873530387878, Recall: 0.5652173757553101

# %%
resnet_based_model.save("AIGeneratedModelresnet.h5")

# %%
resnet_based_model_new = keras.models.load_model("AIGeneratedModelresnet.h5")

# %%
import cv2
import matplotlib.pyplot as plt

# Load the image
image_path = r"C:\Users\vaibh\Downloads\data\ai3.png"

try:
    img = cv2.imread(image_path)

    # Check if the image is loaded successfully
    if img is None:
        raise FileNotFoundError(f"Could not read the image from {image_path}")

    # Resize the image to a larger size
    img = cv2.resize(img, (800, 600))

    # Convert from BGR to RGB
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    # Display the resized image
    plt.imshow(img)
    plt.show()

except Exception as e:
    print(f"Error: {e}")

# %%
import numpy as np

# %%
resize = tf.image.resize(img, (32, 32))

y_pred = model.predict(np.expand_dims(resize/255, 0))
# Out:
# 1/1 [==============================] - 0s 46ms/step

# %%
y_pred
# Out:
# array([[0.40145215]], dtype=float32)

# %%
if y_pred > 0.5: 
    print(f'Predicted class: REAL')
else:
    print(f'Predicted class: SYNTHETIC')
# Out:
# Predicted class: SYNTHETIC

# %% [markdown]
# # Efficientnet

# %%
# Define an EfficientNetB0-based model with additional layers
efficientnet_based_model = models.Sequential()

# Pre-trained EfficientNetB0 base
efficientnet_based_model.add(EfficientNetB0(weights='imagenet', include_top=False, input_shape=(32, 32, 3)))
efficientnet_based_model.add(layers.GlobalAveragePooling2D())

# Additional trainable layers
efficientnet_based_model.add(layers.Dense(512, activation='relu'))
efficientnet_based_model.add(layers.BatchNormalization())
efficientnet_based_model.add(layers.Dropout(0.5))

efficientnet_based_model.add(layers.Dense(256, activation='relu'))
efficientnet_based_model.add(layers.BatchNormalization())
efficientnet_based_model.add(layers.Dropout(0.5))

# Additional dense layers
efficientnet_based_model.add(layers.Dense(128, activation='relu'))
efficientnet_based_model.add(layers.BatchNormalization())
efficientnet_based_model.add(layers.Dropout(0.5))

# Output layer
efficientnet_based_model.add(layers.Dense(1, activation='sigmoid'))

# %%
# Learning rate scheduler
initial_learning_rate = 0.001
def lr_scheduler(epoch, lr):
    return lr * 0.95  # Adjust the decay factor as needed
lr_schedule = LearningRateScheduler(lr_scheduler)
optimizer = Adam(learning_rate=initial_learning_rate)

# %%
# Compile the model
efficientnet_based_model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train the EfficientNetB0-based model
efficient_history = efficientnet_based_model.fit(data, validation_data=cv, epochs=10, callbacks=[lr_schedule])
# Out:
# Epoch 1/10
# 349/349 [==============================] - 91s 260ms/step - loss: 0.0045 - accuracy: 0.9986 - val_loss: 0.8590 - val_accuracy: 0.6739 - lr: 7.3098e-05
# Epoch 2/10
# 349/349 [==============================] - 91s 260ms/step - loss: 0.0063 - accuracy: 0.9982 - val_loss: 0.4024 - val_accuracy: 0.8555 - lr: 6.9443e-05
# Epoch 3/10
# 349/349 [==============================] - 98s 280ms/step - loss: 0.0051 - accuracy: 0.9986 - val_loss: 0.6172 - val_accuracy: 0.8220 - lr: 6.5971e-05
# Epoch 4/10
# 349/349 [==============================] - 95s 270ms/step - loss: 0.0070 - accuracy: 0.9976 - val_loss: 0.2546 - val_accuracy: 0.9067 - lr: 6.2672e-05
# Epoch 5/10
# 349/349 [==============================] - 125s 359ms/step - loss: 0.0077 - accuracy: 0.9977 - val_loss: 1.1795 - val_accuracy: 0.6132 - lr: 5.9539e-05
# Epoch 6/10
# 349/349 [==============================] - 95s 271ms/step - loss: 0.0043 - accuracy: 0.9989 - val_loss: 0.2863 - val_accuracy: 0.8945 - lr: 5.6562e-05
# Epoch 7/10
# 349/349 [==============================] - 95s 271ms/step - loss: 0.0036 - accuracy: 0.9991 - val_loss: 1.4213 - val_accuracy: 0.7142 - lr: 5.3734e-05
# Epoch 8/10
# 349/349 [==============================] - 95s 270ms/step - loss: 0.0018 - accuracy: 0.9996 - val_loss: 0.6862 - val_accuracy: 0.7862 - lr: 5.1047e-05
# Epoch 9/10
# 349/349 [==============================] - 95s 272ms/step - loss: 0.0039 - accuracy: 0.9988 - val_loss: 0.5990 - val_accuracy: 0.8777 - lr: 4.8495e-05
# Epoch 10/10
# 349/349 [==============================] - 124s 354ms/step - loss: 0.0039 - accuracy: 0.9989 - val_loss: 0.6953 - val_accuracy: 0.8247 - lr: 4.6070e-05

# %%
# Evaluate the EfficientNetB0-based model on the test set
test_loss, test_accuracy = efficientnet_based_model.evaluate(test)
print(f'EfficientNetB0 Test Accuracy: {test_accuracy * 100:.2f}%')
# Out:
# 35/35 [==============================] - 8s 70ms/step - loss: 0.7448 - accuracy: 0.8259
# EfficientNetB0 Test Accuracy: 82.59%

# %%
plt.figure(figsize=(12, 4))
# Plot training & validation accuracy values
plt.subplot(1, 2, 1)
plt.plot(efficient_history.history['accuracy'], label='Efficient Train')
plt.plot(efficient_history.history['val_accuracy'], label='Efficient Validation')
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# %%
# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(efficient_history.history['loss'], label='Efficient Train')
plt.plot(efficient_history.history['val_loss'], label='Efficient Validation')
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
from tensorflow.keras.metrics import Precision, Recall

pre = Precision()
rec = Recall()


for batch in test.as_numpy_iterator(): 
    X, y = batch
    yhat = efficientnet_based_model.predict(X)
    pre.update_state(y, yhat)
    rec.update_state(y, yhat)
# Out:
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 133ms/step

# %%
print(f'Precision: {pre.result().numpy()}, Recall: {rec.result().numpy()}')
# Out:
# Precision: 0.8455696105957031, Recall: 0.7198275923728943

# %%
from tensorflow.keras.models import load_model
from keras.models import load_model
from tensorflow import keras

# %%
efficientnet_based_model.save("AIGeneratedModelefficient.h5")

# %%
efficientnet_based_model_new = keras.models.load_model("AIGeneratedModelefficient.h5")

# %%
import cv2
import matplotlib.pyplot as plt

# Load the image
image_path = r"C:\Users\vaibh\Downloads\data\images\real\animals_6.jpeg"

try:
    img = cv2.imread(image_path)

    # Check if the image is loaded successfully
    if img is None:
        raise FileNotFoundError(f"Could not read the image from {image_path}")

    # Resize the image to a larger size
    img = cv2.resize(img, (800, 600))

    # Convert from BGR to RGB
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    # Display the resized image
    plt.imshow(img)
    plt.show()

except Exception as e:
    print(f"Error: {e}")

# %%
import numpy as np

# %%
resize = tf.image.resize(img, (32, 32))

y_pred = efficientnet_based_model.predict(np.expand_dims(resize/255, 0))
# Out:
# 1/1 [==============================] - 0s 110ms/step

# %%
y_pred
# Out:
# array([[0.9989513]], dtype=float32)

# %%
if y_pred > 0.5: 
    print(f'Predicted class: REAL')
else:
    print(f'Predicted class: SYNTHETIC')
# Out:
# Predicted class: REAL
